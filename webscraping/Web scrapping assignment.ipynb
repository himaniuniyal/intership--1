# %%
# !pip install bs4
# !pip install requests

# %% [markdown]
# # 2) Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release) and make data frame

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.imdb.com/chart/top")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
first_title= soup.find_all('td', class_="titleColumn")
first_title
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
#        <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather: Part II</a>
#  <span class="secondaryInfo">(1974)</span>
#  </td>,
#  <td class="titleColumn">
#        4.
#        <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  </td>,
#  <td class="titleColumn">
#        5.
# ...

# %%
movies=[]
for movie in first_title:
    movie=movie.get_text().replace('\n','')
    movie=movie.strip(" ")
    movies.append(movie)
movies
# Out:
# ['1.      The Shawshank Redemption(1994)',
#  '2.      The Godfather(1972)',
#  '3.      The Godfather: Part II(1974)',
#  '4.      The Dark Knight(2008)',
#  '5.      12 Angry Men(1957)',
#  "6.      Schindler's List(1993)",
#  '7.      The Lord of the Rings: The Return of the King(2003)',
#  '8.      Pulp Fiction(1994)',
#  '9.      Il buono, il brutto, il cattivo(1966)',
#  '10.      The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '11.      Fight Club(1999)',
#  '12.      Forrest Gump(1994)',
#  '13.      Inception(2010)',
#  '14.      The Lord of the Rings: The Two Towers(2002)',
#  '15.      Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '16.      The Matrix(1999)',
#  '17.      Goodfellas(1990)',
#  "18.      One Flew Over the Cuckoo's Nest(1975)",
#  '19.      Shichinin no samurai(1954)',
#  '20.      Se7en(1995)',
#  '21.      The Silence of the Lambs(1991)',
#  '22.      Cidade de Deus(2002)',
#  '23.      La vita è bella(1997)',
# ...

# %%
movie= movies[0:100]
movie
# Out:
# ['1.      The Shawshank Redemption(1994)',
#  '2.      The Godfather(1972)',
#  '3.      The Godfather: Part II(1974)',
#  '4.      The Dark Knight(2008)',
#  '5.      12 Angry Men(1957)',
#  "6.      Schindler's List(1993)",
#  '7.      The Lord of the Rings: The Return of the King(2003)',
#  '8.      Pulp Fiction(1994)',
#  '9.      Il buono, il brutto, il cattivo(1966)',
#  '10.      The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '11.      Fight Club(1999)',
#  '12.      Forrest Gump(1994)',
#  '13.      Inception(2010)',
#  '14.      The Lord of the Rings: The Two Towers(2002)',
#  '15.      Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '16.      The Matrix(1999)',
#  '17.      Goodfellas(1990)',
#  "18.      One Flew Over the Cuckoo's Nest(1975)",
#  '19.      Shichinin no samurai(1954)',
#  '20.      Se7en(1995)',
#  '21.      The Silence of the Lambs(1991)',
#  '22.      Cidade de Deus(2002)',
#  '23.      La vita è bella(1997)',
# ...

# %%
scrapped_rating= soup.find_all('td', class_="ratingColumn imdbRating")
scrapped_rating
# Out:
# [<td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 2,495,613 user ratings">9.2</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="9.1 based on 1,721,090 user ratings">9.1</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 1,194,763 user ratings">9.0</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,446,620 user ratings">9.0</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 737,381 user ratings">8.9</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,278,064 user ratings">8.9</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,725,423 user ratings">8.9</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.8 based on 1,927,280 user ratings">8.8</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
# ...

# %%
ratings=[]
for rating in scrapped_rating:
    rating=rating.get_text().replace('\n','')
    
    ratings.append(rating)
ratings
# Out:
# ['9.2',
#  '9.1',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
# ...

# %%
rating= ratings[0:100]
rating
# Out:
# ['9.2',
#  '9.1',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3']

# %%
import pandas as pd
data=pd.DataFrame({'Movie Name':movie,'Ratings': rating})
data
# Out:
#                                            Movie Name Ratings
# 0              1.      The Shawshank Redemption(1994)     9.2
# 1                         2.      The Godfather(1972)     9.1
# 2                3.      The Godfather: Part II(1974)     9.0
# 3                       4.      The Dark Knight(2008)     9.0
# 4                          5.      12 Angry Men(1957)     8.9
# ..                                                ...     ...
# 95                 96.      Requiem for a Dream(2000)     8.3
# 96                 97.      Singin' in the Rain(1952)     8.3
# 97                  98.      North by Northwest(1959)     8.3
# 98  99.      Eternal Sunshine of the Spotless Mind...     8.3
# 99                100.      Ladri di biciclette(1948)     8.3
#
# [100 rows x 2 columns]

# %% [markdown]
# # 3) Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of release) and make data frame

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.imdb.com/list/ls009997493/")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
title= soup.find_all('h3', class_="lister-item-header")
title
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0405508/">Rang De Basanti</a>
#  <span class="lister-item-year text-muted unbold">(2006)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt1187043/">3 Idiots</a>
#  <span class="lister-item-year text-muted unbold">(2009)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt0986264/">Taare Zameen Par</a>
#  <span class="lister-item-year text-muted unbold">(2007)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt0292490/">Dil Chahta Hai</a>
#  <span class="lister-item-year text-muted unbold">(2001)</span>
#  </h3>,
#  <h3 class="lister-item-header">
# ...

# %%
hindi_movies=[]
for movie in title:
    movie=movie.get_text().replace('\n','')
    movie=movie.strip(" ")
    
    hindi_movies.append(movie)
hindi_movies
# Out:
# ['1.Rang De Basanti(2006)',
#  '2.3 Idiots(2009)',
#  '3.Taare Zameen Par(2007)',
#  '4.Dil Chahta Hai(2001)',
#  '5.Swades: We, the People(2004)',
#  '6.Lagaan: Once Upon a Time in India(2001)',
#  '7.Gangs of Wasseypur(2012)',
#  '8.Barfi!(2012)',
#  '9.Anand(1971)',
#  '10.Munna Bhai M.B.B.S.(2003)',
#  '11.A Wednesday(2008)',
#  '12.Andaz Apna Apna(1994)',
#  '13.Sholay(1975)',
#  '14.Bhaag Milkha Bhaag(2013)',
#  '15.Hera Pheri(2000)',
#  '16.Udaan(2010)',
#  '17.Kahaani(2012)',
#  '18.Black(2005)',
#  '19.Chak De! India(2007)',
#  '20.Khosla Ka Ghosla!(2006)',
#  '21.Jo Jeeta Wohi Sikandar(1992)',
#  '22.Zindagi Na Milegi Dobara(2011)',
#  '23.Paan Singh Tomar(2012)',
#  '24.Dilwale Dulhania Le Jayenge(1995)',
#  '25.Omkara(2006)',
#  '26.Lage Raho Munna Bhai(2006)',
#  '27.Iqbal(2005)',
#  '28.The Lunchbox(2013)',
#  '29.Black Friday(2004)',
#  '30.Company(2002)',
#  '31.Golmaal(1979)',
#  '32.Dev.D(2009)',
#  '33.Jaane Bhi Do Yaaro(1983)',
#  '34.OMG: Oh My God!(2012)',
# ...

# %%
hindi_rating=soup.find_all('div', class_="ipl-rating-star small")
hindi_rating
# Out:
# [<div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </span>
#  <span class="ipl-rating-star__rating">8.1</span>
#  </div>,
#  <div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </span>
#  <span class="ipl-rating-star__rating">8.4</span>
#  </div>,
# ...

# %%
ratings_hindi=[]
for rating in hindi_rating:
    rating=rating.get_text().replace('\n','')
    
   
    
    ratings_hindi.append(rating)
ratings_hindi
# Out:
# ['8.1',
#  '8.4',
#  '8.4',
#  '8.1',
#  '8.2',
#  '8.1',
#  '8.2',
#  '8.1',
#  '8.2',
#  '8.1',
#  '8.1',
#  '8.1',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.1',
#  '8.2',
#  '8.2',
#  '8.3',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.1',
#  '8.1',
#  '8.1',
#  '8.1',
#  '7.8',
#  '8.5',
#  '8',
#  '8.6',
#  '8',
#  '8.4',
#  '8.1',
#  '8.2',
#  '8.1',
#  '7.9',
#  '7.9',
#  '8.5',
#  '8.1',
#  '8.4',
#  '8',
#  '8.3',
#  '7.8',
#  '7.9',
#  '8',
#  '7.9',
#  '7.7',
#  '8.1',
#  '7.8',
#  '8.3',
#  '7.7',
#  '7.8',
#  '8.3',
#  '7.8',
#  '8.1',
#  '7.9',
#  '7.7',
#  '7.8',
#  '8.3',
#  '8.4',
#  '7.6',
#  '8.1',
#  '8',
#  '8.1',
#  '7.7',
#  '7.8',
#  '7.8',
#  '7.9',
#  '8',
#  '7.7',
#  '7.3',
#  '7.8',
#  '7.8',
#  '7.9',
#  '8',
#  '7.4',
#  '7.7',
#  '8.1',
#  '7.6',
#  '7.8',
#  '7.7',
#  '7.9',
#  '7.7',
#  '7.8',
#  '7.7',
#  '8',
#  '7.5',
#  '7.8',
#  '7.9',
#  '7.6',
#  '7.6',
#  '8.1',
#  '7.5',
#  '7.6',
#  '7.6',
#  '7.5',
#  '7.7',
#  '7.6',
#  '7.5']

# %%
import pandas as pd
data_1=pd.DataFrame({'Movie Name':hindi_movies,'Ratings': ratings_hindi})
data_1
# Out:
#                         Movie Name Ratings
# 0          1.Rang De Basanti(2006)     8.1
# 1                 2.3 Idiots(2009)     8.4
# 2         3.Taare Zameen Par(2007)     8.4
# 3           4.Dil Chahta Hai(2001)     8.1
# 4   5.Swades: We, the People(2004)     8.2
# ..                             ...     ...
# 95            96.Wake Up Sid(2009)     7.6
# 96               97.Rangeela(1995)     7.5
# 97    98.Shatranj Ke Khilari(1977)     7.7
# 98     99.Pyaar Ka Punchnama(2011)     7.6
# 99         100.Ek Hasina Thi(2004)     7.5
#
# [100 rows x 2 columns]

# %% [markdown]
# # 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:                                                                                                                                                                                                                                  a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
team= soup.find_all('span', class_="u-hide-phablet")
team
# Out:
# [<span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Afghanistan</span>,
#  <span class="u-hide-phablet">Netherlands</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="u-hide-phablet">Scotland</span>,
#  <span class="u-hide-phablet">Zimbabwe</span>,
#  <span class="u-hide-phablet">Oman</span>,
#  <span class="u-hide-phablet">Nepal</span>,
#  <span class="u-hide-phablet">UAE</span>,
#  <span class="u-hide-phablet">United States</span>,
#  <span class="u-hide-phablet">Namibia</span>,
#  <span class="u-hide-phablet">Papua New Guinea</span>,
# ...

# %%
teams_men1=[]
for teams in team:
    teams=teams.get_text().replace('\n','')
    
    teams_men1.append(teams)
teams_men1
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan',
#  'Netherlands',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Oman',
#  'Nepal',
#  'UAE',
#  'United States',
#  'Namibia',
#  'Papua New Guinea',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
#Top 10 ODI Teams
team_men=teams_men1[0:10]
team_men
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan']

# %%
point_1=soup.find('td', class_="rankings-block__banner--points")
point_1.text
# Out:
# '2,054'

# %%
points=soup.find_all('td', class_="table-body__cell u-center-text")
points
# Out:
# [<td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,793</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">3,244</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,624</td>,
#  <td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,459</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,524</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">2,740</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">2,523</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">2,657</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
point_team=[]
for point in points:
    point=point.get_text().replace('\n','')

    
    point_team.append(point)
    
point_team
# Out:
# ['32',
#  '3,793',
#  '28',
#  '3,244',
#  '32',
#  '3,624',
#  '25',
#  '2,459',
#  '27',
#  '2,524',
#  '30',
#  '2,740',
#  '30',
#  '2,523',
#  '32',
#  '2,657',
#  '17',
#  '1,054',
#  '7',
#  '336',
#  '25',
#  '1,145',
#  '10',
#  '452',
#  '20',
#  '764',
#  '14',
#  '524',
#  '11',
#  '330',
#  '9',
#  '190',
#  '14',
#  '232',
#  '6',
#  '97',
#  '13',
#  '0']

# %%
point_team1=point_team[1:19:2]
point_team1
# Out:
# ['3,793',
#  '3,244',
#  '3,624',
#  '2,459',
#  '2,524',
#  '2,740',
#  '2,523',
#  '2,657',
#  '1,054']

# %%
#Top 10 odi Points
final_point1= [point_1.text] + [point_team1]
final_point1
# Out:
# ['2,054',
#  ['3,793',
#   '3,244',
#   '3,624',
#   '2,459',
#   '2,524',
#   '2,740',
#   '2,523',
#   '2,657',
#   '1,054']]

# %%
matches1=point_team[0:18:2]
matches1
# Out:
# ['32', '28', '32', '25', '27', '30', '30', '32', '17']

# %%
match=soup.find('td', class_="rankings-block__banner--matches")
 
match.text
# Out:
# '17'

# %%
# Top Ten ODI Matches
matches=[match.text]+[matches1]
matches
# Out:
# ['17', ['32', '28', '32', '25', '27', '30', '30', '32', '17']]

# %%
rating=soup.find('td', class_="rankings-block__banner--rating u-text-right")
rating.text.replace ('\n','')
rating_new= rating.text.replace ('\n','')
rating_new
# Out:
# '                            121                            '

# %%
rating1=soup.find_all('td', class_="table-body__cell u-text-right rating")
rating1
# Out:
# [<td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">116</td>,
#  <td class="table-body__cell u-text-right rating">113</td>,
#  <td class="table-body__cell u-text-right rating">98</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">91</td>,
#  <td class="table-body__cell u-text-right rating">84</td>,
#  <td class="table-body__cell u-text-right rating">83</td>,
#  <td class="table-body__cell u-text-right rating">62</td>,
#  <td class="table-body__cell u-text-right rating">48</td>,
#  <td class="table-body__cell u-text-right rating">46</td>,
#  <td class="table-body__cell u-text-right rating">45</td>,
#  <td class="table-body__cell u-text-right rating">38</td>,
#  <td class="table-body__cell u-text-right rating">37</td>,
#  <td class="table-body__cell u-text-right rating">30</td>,
#  <td class="table-body__cell u-text-right rating">21</td>,
# ...

# %%
rating_team=[]
for rating in rating1:
    rating=rating.get_text().replace('\n','')

    
    rating_team.append(rating)
    
rating_team
# Out:
# ['119',
#  '116',
#  '113',
#  '98',
#  '93',
#  '91',
#  '84',
#  '83',
#  '62',
#  '48',
#  '46',
#  '45',
#  '38',
#  '37',
#  '30',
#  '21',
#  '17',
#  '16',
#  '0']

# %%
#top 10 ODI ratings
rating_final=[rating_new]+[rating_team]
rating_final
# Out:
# ['                            121                            ',
#  ['119',
#   '116',
#   '113',
#   '98',
#   '93',
#   '91',
#   '84',
#   '83',
#   '62',
#   '48',
#   '46',
#   '45',
#   '38',
#   '37',
#   '30',
#   '21',
#   '17',
#   '16',
#   '0']]

# %% [markdown]
# # 4. b) Top 10 ODI Batsmen in men along with the records of their team and rating

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
batsmen=soup.find('div', class_="rankings-block__banner--name-large")
batsmen.text
batsmen1= batsmen.text
batsmen1
# Out:
# 'Babar Azam'

# %%
batsmen=soup.find_all('td', class_="table-body__cell rankings-table__name name")
batsmen
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/164">Virat Kohli</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/506">Jonny Bairstow</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/2751">Shai Hope</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
# ...

# %%
players=[]
for player in batsmen:
    player=player.get_text().replace('\n','')


    
    players.append(player)
    
players
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Shai Hope',
#  'Kane Williamson',
#  'Quinton de Kock',
#  'Fakhar Zaman',
#  'Joe Root',
#  'Mushfiqur Rahim',
#  'Imam-ul-Haq',
#  'Martin Guptill',
#  'Shikhar Dhawan',
#  'Steve Smith',
#  'Jason Roy',
#  'Rassie van der Dussen',
#  'Glenn Maxwell',
#  'Tamim Iqbal',
#  'Alex Carey',
#  'Paul Stirling',
#  'Ben Stokes',
#  'Eoin Morgan',
#  'Shakib Al Hasan',
#  'Lokesh Rahul',
#  'Tom Latham',
#  'David Miller',
#  'Nicholas Pooran',
#  'Jos Buttler',
#  'Shimron Hetmyer',
#  'Haris Sohail',
#  'Janneman Malan',
#  'Henry Nicholls',
#  'Kyle Coetzer',
#  'Mahmudullah',
#  'Brendan Taylor',
#  'Avishka Fernando',
#  'Andrew Balbirnie',
#  'Aqib Ilyas',
#  'Rahmat Shah',
#  'Evin Lewis',
#  'Litton Das',
#  'Kedar Jadhav',
#  'Kusal Perera',
#  'Hardik Pandya',
#  'Sean Williams',
#  'Sikandar Raza',
#  'Angelo Mathews',
#  'Danushka Gunathilaka',
#  'Imad Wasim',
# ...

# %%
player_top10= players[0:9]
player_top10
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Shai Hope',
#  'Kane Williamson',
#  'Quinton de Kock']

# %%
batsmen_top10=[batsmen1] +[player_top10]
batsmen_top10
# Out:
# ['Babar Azam',
#  ['Virat Kohli',
#   'Rohit Sharma',
#   'Ross Taylor',
#   'Aaron Finch',
#   'Jonny Bairstow',
#   'David Warner',
#   'Shai Hope',
#   'Kane Williamson',
#   'Quinton de Kock']]

# %%
Country=soup.find('div', class_="rankings-block__banner--nationality")
Country.text
Team= Country.text.replace('\n','')
Team
# Out:
# 'PAK                    '

# %%
Rating_top=soup.find('div',class_="rankings-block__banner--rating")
Rating_top.text
Rating_top1= Rating_top.text
Rating_top1
# Out:
# '873'

# %%
Country1=soup.find_all('span', class_="table-body__logo-text")
Country1
# Out:
# [<span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
# ...

# %%
Rating1=soup.find_all('td',class_="table-body__cell rating")
Rating1
# Out:
# [<td class="table-body__cell rating">844</td>,
#  <td class="table-body__cell rating">813</td>,
#  <td class="table-body__cell rating">801</td>,
#  <td class="table-body__cell rating">779</td>,
#  <td class="table-body__cell rating">775</td>,
#  <td class="table-body__cell rating">762</td>,
#  <td class="table-body__cell rating">758</td>,
#  <td class="table-body__cell rating">754</td>,
#  <td class="table-body__cell rating">747</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">740</td>,
#  <td class="table-body__cell rating">723</td>,
#  <td class="table-body__cell rating">717</td>,
#  <td class="table-body__cell rating">707</td>,
#  <td class="table-body__cell rating">704</td>,
#  <td class="table-body__cell rating">696</td>,
#  <td class="table-body__cell rating">687</td>,
#  <td class="table-body__cell rating">674</td>,
#  <td class="table-body__cell rating">674</td>,
#  <td class="table-body__cell rating">670</td>,
# ...

# %%
Team10=[]
for team in Country1:
    team=team.get_text().replace('\n','')


    
    Team10.append(team)
    
Team10
# Out:
# ['IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'AUS',
#  'WI',
#  'NZ',
#  'SA',
#  'PAK',
#  'ENG',
#  'BAN',
#  'PAK',
#  'NZ',
#  'IND',
#  'AUS',
#  'ENG',
#  'SA',
#  'AUS',
#  'BAN',
#  'AUS',
#  'IRE',
#  'ENG',
#  'ENG',
#  'BAN',
#  'IND',
#  'NZ',
#  'SA',
#  'WI',
#  'ENG',
#  'WI',
#  'PAK',
#  'SA',
#  'NZ',
#  'SCO',
#  'BAN',
#  'ZIM',
#  'SL',
#  'IRE',
#  'OMA',
#  'AFG',
#  'WI',
#  'BAN',
#  'IND',
#  'SL',
#  'IND',
#  'ZIM',
#  'ZIM',
#  'SL',
#  'SL',
#  'PAK',
#  'BAN',
#  'SL',
#  'AUS',
#  'SCO',
#  'NZ',
#  'AFG',
#  'PAK',
#  'AFG',
#  'AUS',
#  'NZ',
#  'SL',
#  'AFG',
#  'AUS',
#  'SL',
#  'IRE',
#  'AFG',
#  'SCO',
#  'SA',
#  'IRE',
#  'SA',
#  'ZIM',
#  'SL',
#  'IND',
#  'UAE',
#  'SA',
#  'NZ',
#  'WI',
#  'PNG',
#  'IND',
#  'BAN',
#  'AFG',
#  'SCO',
#  'SL',
#  'IND',
#  'SL',
#  'AUS',
#  'SA',
#  'WI',
#  'WI',
#  'AFG',
#  'PAK',
#  'IRE',
#  'SL',
#  'ENG',
#  'ENG',
#  'SCO',
#  'ZIM',
#  'ENG']

# %%
Rating10=[]
for rating in Rating1:
    rating=rating.get_text().replace('\n','')


    
    Rating10.append(rating)
    
Rating10
# Out:
# ['844',
#  '813',
#  '801',
#  '779',
#  '775',
#  '762',
#  '758',
#  '754',
#  '747',
#  '741',
#  '740',
#  '723',
#  '717',
#  '707',
#  '704',
#  '696',
#  '687',
#  '674',
#  '674',
#  '670',
#  '669',
#  '658',
#  '651',
#  '650',
#  '641',
#  '636',
#  '624',
#  '622',
#  '615',
#  '608',
#  '607',
#  '594',
#  '589',
#  '581',
#  '573',
#  '571',
#  '569',
#  '568',
#  '568',
#  '567',
#  '559',
#  '558',
#  '558',
#  '552',
#  '551',
#  '548',
#  '545',
#  '542',
#  '542',
#  '530',
#  '525',
#  '521',
#  '518',
#  '517',
#  '508',
#  '507',
#  '506',
#  '504',
#  '498',
#  '498',
#  '495',
#  '495',
#  '494',
#  '489',
#  '484',
#  '484',
#  '479',
#  '479',
#  '478',
#  '477',
#  '476',
#  '476',
#  '473',
#  '472',
#  '471',
#  '462',
#  '460',
#  '446',
#  '434',
#  '434',
#  '433',
#  '432',
#  '430',
#  '429',
#  '426',
#  '424',
#  '424',
#  '423',
#  '419',
#  '416',
#  '415',
#  '414',
#  '412',
#  '409',
#  '404',
#  '403',
#  '398',
#  '397',
#  '396']

# %%
Team_top10=[Team]+[Team10[0:9]]
Team_top10
# Out:
# ['PAK                    ',
#  ['IND', 'IND', 'NZ', 'AUS', 'ENG', 'AUS', 'WI', 'NZ', 'SA']]

# %%
Rating_top10=[Rating_top1]+[Rating10[0:9]]
Rating_top10
# Out:
# ['873', ['844', '813', '801', '779', '775', '762', '758', '754', '747']]

# %%
batsmen_top10=[batsmen1] +[player_top10]
batsmen_top10
# Out:
# ['Babar Azam',
#  ['Virat Kohli',
#   'Rohit Sharma',
#   'Ross Taylor',
#   'Aaron Finch',
#   'Jonny Bairstow',
#   'David Warner',
#   'Shai Hope',
#   'Kane Williamson',
#   'Quinton de Kock']]

# %% [markdown]
# # Q4 c) Top 10 ODI bowlers along with the records of their team and rating

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
ODIbowler=soup.find('div', class_="rankings-block__banner--name-large")

Bowler=ODIbowler.text
Bowler
# Out:
# 'Trent Boult'

# %%
bowler=soup.find_all('td', class_="table-body__cell rankings-table__name name")
bowler
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/857">Josh Hazlewood</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/4572">Mujeeb Ur Rahman</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/967">Chris Woakes</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1597">Mehedi Hasan</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1505">Matt Henry</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1124">Jasprit Bumrah</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/490">Mitchell Starc</a>
#  </td>,
# ...

# %%
bowlers=[]
for player1 in bowler:
    player1=player1.get_text().replace('\n','')


    
    bowlers.append(player1)
    
bowlers
# Out:
# ['Josh Hazlewood',
#  'Mujeeb Ur Rahman',
#  'Chris Woakes',
#  'Mehedi Hasan',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mitchell Starc',
#  'Shakib Al Hasan',
#  'Kagiso Rabada',
#  'Mustafizur Rahman',
#  'Pat Cummins',
#  'Shaheen Afridi',
#  'Mohammad Amir',
#  'Rashid Khan',
#  'Adam Zampa',
#  'Bhuvneshwar Kumar',
#  'Lachlan Ferguson',
#  'Jofra Archer',
#  'Yuzvendra Chahal',
#  'Mohammad Nabi',
#  'Mark Wood',
#  'Alzarri Joseph',
#  'Lungi Ngidi',
#  'Mitchell Santner',
#  'Akila Dananjaya',
#  'Andy McBrine',
#  'Mohammad Shami',
#  'Tabraiz Shamsi',
#  'Kuldeep Yadav',
#  'Ravindra Jadeja',
#  'Sheldon Cottrell',
#  'Wanindu Hasaranga',
#  'Ahmed Raza',
#  'Dushmantha Chameera',
#  'Shadab Khan',
#  'Colin de Grandhomme',
#  'Simi Singh',
#  'David Willey',
#  'Tim Southee',
#  'Adil Rashid',
#  'Ish Sodhi',
#  'Keshav Maharaj',
#  'Mark Watt',
#  'Imad Wasim',
#  'Hasan Ali',
#  'Usman Khan',
#  'Jhye Richardson',
#  'Rohan Mustafa',
#  'Blessing Muzarabani',
# ...

# %%
bowlers_top10= bowlers[0:9]
bowlers_top10
# Out:
# ['Josh Hazlewood',
#  'Mujeeb Ur Rahman',
#  'Chris Woakes',
#  'Mehedi Hasan',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mitchell Starc',
#  'Shakib Al Hasan',
#  'Kagiso Rabada']

# %%
bowler_top10=[Bowler] +[bowlers_top10]
bowler_top10
# Out:
# ['Trent Boult',
#  ['Josh Hazlewood',
#   'Mujeeb Ur Rahman',
#   'Chris Woakes',
#   'Mehedi Hasan',
#   'Matt Henry',
#   'Jasprit Bumrah',
#   'Mitchell Starc',
#   'Shakib Al Hasan',
#   'Kagiso Rabada']]

# %%
Country_1=soup.find('div', class_="rankings-block__banner--nationality")
Country_1.text
Team_1= Country_1.text.replace('\n','')
Team_1
# Out:
# 'NZ                    '

# %%
Rating_1=soup.find('td',class_="table-body__cell rating")
Rating_1.text
Rating_top= Rating_1.text
Rating_top
# Out:
# '709'

# %%
Country=soup.find_all('span', class_="table-body__logo-text")
Country
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
# ...

# %%
Rating01=soup.find_all('td',class_="table-body__cell rating")
Rating01
# Out:
# [<td class="table-body__cell rating">709</td>,
#  <td class="table-body__cell rating">708</td>,
#  <td class="table-body__cell rating">700</td>,
#  <td class="table-body__cell rating">692</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">679</td>,
#  <td class="table-body__cell rating">652</td>,
#  <td class="table-body__cell rating">650</td>,
#  <td class="table-body__cell rating">646</td>,
#  <td class="table-body__cell rating">640</td>,
#  <td class="table-body__cell rating">636</td>,
#  <td class="table-body__cell rating">630</td>,
#  <td class="table-body__cell rating">628</td>,
#  <td class="table-body__cell rating">626</td>,
#  <td class="table-body__cell rating">625</td>,
#  <td class="table-body__cell rating">621</td>,
#  <td class="table-body__cell rating">619</td>,
#  <td class="table-body__cell rating">609</td>,
#  <td class="table-body__cell rating">603</td>,
#  <td class="table-body__cell rating">596</td>,
# ...

# %%
Teamtop10=[]
for team1 in Country:
    team1=team1.get_text().replace('\n','')


    
    Teamtop10.append(team1)
    
Teamtop10
# Out:
# ['AUS',
#  'AFG',
#  'ENG',
#  'BAN',
#  'NZ',
#  'IND',
#  'AUS',
#  'BAN',
#  'SA',
#  'BAN',
#  'AUS',
#  'PAK',
#  'PAK',
#  'AFG',
#  'AUS',
#  'IND',
#  'NZ',
#  'ENG',
#  'IND',
#  'AFG',
#  'ENG',
#  'WI',
#  'SA',
#  'NZ',
#  'SL',
#  'IRE',
#  'IND',
#  'SA',
#  'IND',
#  'IND',
#  'WI',
#  'SL',
#  'UAE',
#  'SL',
#  'PAK',
#  'NZ',
#  'IRE',
#  'ENG',
#  'NZ',
#  'ENG',
#  '',
#  'SA',
#  'SCO',
#  'PAK',
#  'PAK',
#  'PAK',
#  'AUS',
#  'UAE',
#  'ZIM',
#  'SA',
#  'BAN',
#  'BAN',
#  'SCO',
#  'IRE',
#  'NZ',
#  'ZIM',
#  'ENG',
#  'SL',
#  'WI',
#  'ENG',
#  'PAK',
#  'PAK',
#  'WI',
#  'ENG',
#  'SL',
#  'AUS',
#  'BAN',
#  'SA',
#  'SCO',
#  'ZIM',
#  'USA',
#  'AUS',
#  'ZIM',
#  'ENG',
#  'IND',
#  'IRE',
#  'SL',
#  'NEP',
#  'BAN',
#  'AFG',
#  'IND',
#  'SCO',
#  'AUS',
#  'IRE',
#  'AUS',
#  'OMA',
#  'PNG',
#  'BAN',
#  'OMA',
#  'PNG',
#  'PAK',
#  'SL',
#  'ZIM',
#  'NED',
#  'WI',
#  'NZ',
#  'PNG',
#  'SCO',
#  'AFG']

# %%
Rating_10=[]
for rating in Rating01:
    rating=rating.get_text().replace('\n','')


    
    Rating_10.append(rating)
    
Rating_10
# Out:
# ['709',
#  '708',
#  '700',
#  '692',
#  '691',
#  '679',
#  '652',
#  '650',
#  '646',
#  '640',
#  '636',
#  '630',
#  '628',
#  '626',
#  '625',
#  '621',
#  '619',
#  '609',
#  '603',
#  '596',
#  '594',
#  '592',
#  '590',
#  '583',
#  '583',
#  '579',
#  '566',
#  '562',
#  '562',
#  '550',
#  '541',
#  '531',
#  '531',
#  '525',
#  '517',
#  '508',
#  '507',
#  '501',
#  '500',
#  '497',
#  '496',
#  '494',
#  '490',
#  '488',
#  '483',
#  '482',
#  '480',
#  '477',
#  '470',
#  '469',
#  '469',
#  '468',
#  '467',
#  '463',
#  '458',
#  '458',
#  '454',
#  '453',
#  '451',
#  '449',
#  '447',
#  '445',
#  '443',
#  '436',
#  '436',
#  '436',
#  '434',
#  '432',
#  '427',
#  '424',
#  '419',
#  '416',
#  '413',
#  '410',
#  '405',
#  '405',
#  '401',
#  '400',
#  '400',
#  '399',
#  '394',
#  '394',
#  '390',
#  '385',
#  '377',
#  '377',
#  '375',
#  '374',
#  '373',
#  '371',
#  '370',
#  '370',
#  '362',
#  '358',
#  '355',
#  '352',
#  '351',
#  '351',
#  '347']

# %%
Team_ODI10=[Team_1]+[Teamtop10[0:9]]
Team_ODI10
# Out:
# ['NZ                    ',
#  ['AUS', 'AFG', 'ENG', 'BAN', 'NZ', 'IND', 'AUS', 'BAN', 'SA']]

# %%
Rating_ODI10=[Rating_top]+[Rating_10[0:9]]
Rating_ODI10
# Out:
# ['709', ['709', '708', '700', '692', '691', '679', '652', '650', '646']]

# %% [markdown]
# # 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape: a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
Team_w=soup.find_all('span', class_="u-hide-phablet")
Team_w
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Zimbabwe</span>,
#  <span class="icn icn-facebook-circle u-hide-phablet"></span>,
#  <span class="icn icn-twitter-circle u-hide-phablet"></span>,
#  <span class="icn icn-instagram-circle u-hide-phablet"></span>,
#  <span class="icn icn-youtube-circle u-hide-phablet"></span>,
#  <span class="icn icn-tiktok-circle u-hide-phablet"></span>]

# %%
Team_W=[]
for team in Team_w:
    team=team.get_text().replace('\n','')


    
    Team_W.append(team)
    
Team_W[0:10]
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Ireland',
#  'Sri Lanka']

# %%
matches_w=soup.find('td', class_="rankings-block__banner--matches")
matches_w.text
match=matches_w.text
match
# Out:
# '17'

# %%
Matches_w=soup.find_all('td', class_="table-body__cell u-center-text")
Matches_w
# Out:
# [<td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,307</td>,
#  <td class="table-body__cell u-center-text">18</td>,
#  <td class="table-body__cell u-center-text">2,148</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,899</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">475</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">1,668</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">1,658</td>,
#  <td class="table-body__cell u-center-text">18</td>,
#  <td class="table-body__cell u-center-text">1,226</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">240</td>,
#  <td class="table-body__cell u-center-text">5</td>,
# ...

# %%
Matches_W=[]
for match in Matches_w:
    match=match.get_text().replace('\n','')


    
    Matches_W.append(match)
    
Matches_W[0:19:2]
Matches_odi_w=Matches_W[0:19:2]
Matches_odi_w
# Out:
# ['19', '18', '17', '5', '19', '19', '18', '5', '5', '7']

# %%
ODI_matches= [match]+[Matches_odi_w]
ODI_matches
# Out:
# ['0', ['19', '18', '17', '5', '19', '19', '18', '5', '5', '7']]

# %%
Matches_odi=Matches_W[1:19:2]
Matches_odi
Point=Matches_odi
Point
# Out:
# ['2,307', '2,148', '1,899', '475', '1,668', '1,658', '1,226', '240', '233']

# %%
point_w=soup.find('td', class_="rankings-block__banner--points")
point_w.text
Point_w=point_w.text
Point_w
# Out:
# '2,746'

# %%
Point_ODI=[Point_w]+[Point]
Point_ODI
# Out:
# ['2,746',
#  ['2,307', '2,148', '1,899', '475', '1,668', '1,658', '1,226', '240', '233']]

# %%
rating=soup.find('td', class_="rankings-block__banner--rating u-text-right")
rating.text.replace('\n','')
rating1= rating.text.replace('\n','')
rating1
# Out:
# '                            162                            '

# %%
rating=soup.find_all('td',class_="table-body__cell u-text-right rating")
rating
# Out:
# [<td class="table-body__cell u-text-right rating">121</td>,
#  <td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">112</td>,
#  <td class="table-body__cell u-text-right rating">95</td>,
#  <td class="table-body__cell u-text-right rating">88</td>,
#  <td class="table-body__cell u-text-right rating">87</td>,
#  <td class="table-body__cell u-text-right rating">68</td>,
#  <td class="table-body__cell u-text-right rating">48</td>,
#  <td class="table-body__cell u-text-right rating">47</td>,
#  <td class="table-body__cell u-text-right rating">0</td>]

# %%
Rating=[]
for rating_1 in rating:
    rating_1= rating_1.get_text().replace('\n','')
    
    Rating.append(rating_1)
    
Rating
# Out:
# ['121', '119', '112', '95', '88', '87', '68', '48', '47', '0']

# %%
Rating_ODI_W=[rating1]+[Rating]
Rating_ODI_W
# Out:
# ['                            162                            ',
#  ['121', '119', '112', '95', '88', '87', '68', '48', '47', '0']]

# %% [markdown]
# # Q5. b) Top 10 women’s ODI players along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
w_b=soup.find('div', class_="rankings-block__banner--name")
w_b.text
w=w_b.text
w
# Out:
# 'Lizelle Lee'

# %%
w_1=soup.find_all('td', class_="table-body__cell name")
w_1
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/558">Mithali Raj</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1817">Beth Mooney</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/552">Heather Knight</a>
#  </td>,
#  <td class="table-body__cell name">
# ...

# %%
Names=[]

for w_l in w_1:
    w_l=w_l.get_text().replace('\n','')
    
    Names.append(w_l)
    
Names[0:10]
N= Names[0:10]
N
# Out:
# ['Alyssa Healy',
#  'Mithali Raj',
#  'Tammy Beaumont',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Heather Knight',
#  'Laura Wolvaardt',
#  'Jhulan Goswami']

# %%
Names_Wteam=[w]+[N]
Names_Wteam
# Out:
# ['Lizelle Lee',
#  ['Alyssa Healy',
#   'Mithali Raj',
#   'Tammy Beaumont',
#   'Amy Satterthwaite',
#   'Smriti Mandhana',
#   'Meg Lanning',
#   'Beth Mooney',
#   'Heather Knight',
#   'Laura Wolvaardt',
#   'Jhulan Goswami']]

# %%
T_w=soup.find('div', class_="rankings-block__banner--nationality")
T_w.text.replace("\n",'')
# Out:
# 'SA                            761'

# %%
t_w=soup.find_all('span', class_="table-body__logo-text")
t_w
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">ENG</span>,
# ...

# %%
Team_w=[]
for team in t_w:
    team= team.get_text().replace('\n','')
    
    Team_w.append(team)
Team_w
# Out:
# ['AUS',
#  'IND',
#  'ENG',
#  'NZ',
#  'IND',
#  'AUS',
#  'AUS',
#  'ENG',
#  'SA',
#  'IND',
#  'AUS',
#  'SA',
#  'ENG',
#  'SA',
#  'ENG',
#  'SA',
#  'ENG',
#  'ENG',
#  'ENG',
#  'AUS',
#  'WI',
#  'IND',
#  'AUS',
#  'SA',
#  'AUS',
#  'ENG',
#  'WI']

# %%
r_w=soup.find_all('td', class_="table-body__cell u-text-right rating")
r_w
# Out:
# [<td class="table-body__cell u-text-right rating">750</td>,
#  <td class="table-body__cell u-text-right rating">738</td>,
#  <td class="table-body__cell u-text-right rating">728</td>,
#  <td class="table-body__cell u-text-right rating">717</td>,
#  <td class="table-body__cell u-text-right rating">710</td>,
#  <td class="table-body__cell u-text-right rating">699</td>,
#  <td class="table-body__cell u-text-right rating">690</td>,
#  <td class="table-body__cell u-text-right rating">674</td>,
#  <td class="table-body__cell u-text-right rating">672</td>,
#  <td class="table-body__cell u-text-right rating">727</td>,
#  <td class="table-body__cell u-text-right rating">717</td>,
#  <td class="table-body__cell u-text-right rating">715</td>,
#  <td class="table-body__cell u-text-right rating">701</td>,
#  <td class="table-body__cell u-text-right rating">688</td>,
#  <td class="table-body__cell u-text-right rating">666</td>,
#  <td class="table-body__cell u-text-right rating">643</td>,
# ...

# %%
Rating_w=[]
for r in r_w:
    r= r.get_text().replace('\n','')
    
    Rating_w.append(r)
    
Rating_w
# Out:
# ['750',
#  '738',
#  '728',
#  '717',
#  '710',
#  '699',
#  '690',
#  '674',
#  '672',
#  '727',
#  '717',
#  '715',
#  '701',
#  '688',
#  '666',
#  '643',
#  '598',
#  '589',
#  '372',
#  '365',
#  '314',
#  '299',
#  '275',
#  '274',
#  '272',
#  '272',
#  '271']

# %% [markdown]
# # Q5.c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
Name=[]
for i in soup.find_all("div", class_="rankings-block__banner--name-large"):
    Name.append(i.text)
Name
# Out:
# ['Marizanne Kapp']

# %%
Name1=[]
for i in soup.find_all("td", class_="table-body__cell rankings-table__name name"):
    Name1.append(i.text.replace("\n",''))
Name1
# Out:
# ['Natalie Sciver',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Deepti Sharma',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Hayley Matthews',
#  'Jess Jonassen',
#  'Katherine Brunt',
#  'Jhulan Goswami',
#  'Sophie Devine',
#  'Rumana Ahmed',
#  'Heather Knight',
#  'Amelia Kerr',
#  'Nida Dar',
#  'Shikha Pandey',
#  'Kate Cross',
#  'Lea Tahuhu',
#  'Chamari Athapaththu']

# %%
Team=[]
for i in soup.find_all("div", class_="rankings-block__banner--nationality"):
    Team.append(i.text.replace("\n",''))
Team
# Out:
# ['SA                    ']

# %%
Rating=[]
for i in soup.find_all("div", class_="rankings-block__banner--rating"):
    Rating.append(i.text.replace("\n",''))
Rating
# Out:
# ['384']

# %%
Team1=[]
for i in soup.find_all("span", class_="table-body__logo-text"):
    Team1.append(i.text.replace("\n",''))
Team1
# Out:
# ['ENG',
#  'AUS',
#  'WI',
#  'IND',
#  'AUS',
#  'SA',
#  'WI',
#  'AUS',
#  'ENG',
#  'IND',
#  'NZ',
#  'BAN',
#  'ENG',
#  'NZ',
#  'PAK',
#  'IND',
#  'ENG',
#  'NZ',
#  'SL']

# %%
Rating1=[]
for i in soup.find_all("td", class_="table-body__cell rating"):
    Rating1.append(i.text.replace("\n",''))
Rating1
# Out:
# ['372',
#  '365',
#  '319',
#  '299',
#  '275',
#  '274',
#  '272',
#  '272',
#  '272',
#  '251',
#  '248',
#  '195',
#  '195',
#  '193',
#  '186',
#  '173',
#  '141',
#  '140',
#  '136']

# %% [markdown]
# # 6) Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content and the code for the video from the link for the youtube video from the post.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://coreyms.com/")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
Heading=[]
for i in soup.find_all("header", class_="entry-header"):
    Heading.append(i.text)
Heading
# Out:
# ['Python Tutorial: Zip Files – Creating and Extracting Zip Archives\nNovember 19, 2019 by Corey Schafer Leave a Comment ',
#  'Python Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey\nOctober 17, 2019 by Corey Schafer Leave a Comment ',
#  'Python Multiprocessing Tutorial: Run Code in Parallel Using the Multiprocessing Module\nSeptember 21, 2019 by Corey Schafer Leave a Comment ',
#  'Python Threading Tutorial: Run Code Concurrently Using the Threading Module\nSeptember 12, 2019 by Corey Schafer Leave a Comment ',
#  'Update (2019-09-03)\nSeptember 3, 2019 by Corey Schafer Leave a Comment ',
#  'Python Quick Tip: The Difference Between “==” and “is” (Equality vs Identity)\nAugust 6, 2019 by Corey Schafer Leave a Comment ',
#  'Python Tutorial: Calling External Commands Using the Subprocess Module\nJuly 24, 2019 by Corey Schafer Leave a Comment ',
# ...

# %%
Date=[]
for i in soup.find_all("time", class_="entry-time"):
    Date.append(i.text)
Date
# Out:
# ['November 19, 2019',
#  'October 17, 2019',
#  'September 21, 2019',
#  'September 12, 2019',
#  'September 3, 2019',
#  'August 6, 2019',
#  'July 24, 2019',
#  'May 1, 2019',
#  'May 1, 2019',
#  'April 24, 2019']

# %%
Content=[]
for i in soup.find_all("div", class_="entry-content"):
    Content.append(i.text)
Content
# Out:
# ['\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n',
#  '\nIn this Python Programming video, we will be learning how to download and analyze real-world data from the 2019 Stack Overflow Developer Survey. This is terrific practice for anyone getting into the data science field. We will learn different ways to analyze this data and also some best practices. Let’s get started…\n\n\n\n',
#  '\nIn this Python Programming video, we will be learning how to run code in parallel using the multiprocessing module. We will also look at how to process multiple high-resolution images at the same time using a ProcessPoolExecutor from the concurrent.futures module. Let’s get started…\n\n\n\n',
# ...

# %%
for links in soup.find_all("a"):
    link=links.get('href')
    print(link)
# Out:
# https://coreyms.com/
# https://coreyms.com/
# https://www.youtube.com/user/schafer5
# https://github.com/CoreyMSchafer
# https://plus.google.com/+CoreySchafer44/posts
# https://twitter.com/CoreyMSchafer
# https://www.instagram.com/coreymschafer/
# http://coreyms.com/feed/
# https://coreyms.com/contact
# http://coreyms.com/portfolio
# https://coreyms.com/category/development
# https://coreyms.com/category/development/python
# https://coreyms.com/category/development/git
# https://coreyms.com/category/development/terminal
# https://coreyms.com/category/development/javascript
# https://coreyms.com/category/development/wordpress
# https://coreyms.com/category/web-design
# https://coreyms.com/category/web-design/css
# https://coreyms.com/category/diy
# https://coreyms.com/category/diy/woodworking
# https://coreyms.com/category/diy/home-improvement
# https://coreyms.com/contributors
# https://coreyms.com/support
# https://coreyms.com/giveaway
# ...
